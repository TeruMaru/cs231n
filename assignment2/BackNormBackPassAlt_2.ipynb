# %% [markdown]
# 3/ Calculate $\frac{\partial l}{\partial Y} \cdot \frac{\partial Y}{\partial \hat{X}} \cdot\frac{\partial \hat{X}}{\partial \vec{\sigma}}\cdot\frac{\partial \vec{\sigma}}{X}$
#
# \begin{align*}
# & \vec{u} = \frac{1}{\vec{\sigma}}=
# \begin{bmatrix}
# \frac{1}{\sigma_1} & \frac{1}{\sigma_2} &...&\frac{1}{\sigma_N}
# \end{bmatrix}
# & \rightarrow
# \underset{D\times D}{\frac{\partial \vec{u}}{\partial \vec{\sigma}}} & =
# \begin{bmatrix}
# \frac{\partial u_1}{\partial{\sigma_1}} & \frac{\partial u_1}{\partial{\sigma_2}} & ... & \frac{\partial u_1}{\partial{\sigma_N}}\\
# \frac{\partial u_2}{\partial{\sigma_1}} & \frac{\partial u_2}{\partial{\sigma_2}} & ... & \frac{\partial u_2}{\partial{\sigma_N}}\\
# ...&...&...&...\\
# \frac{\partial u_N}{\partial{\sigma_1}} & \frac{\partial u_N}{\partial{\sigma_2}} & ... & \frac{\partial u_D}{\partial{\sigma_D}}\\
# \end{bmatrix}=
# \begin{bmatrix}
# \frac{\partial u_1}{\partial{\sigma_1}} & 0 & ... & 0\\
# 0 & \frac{\partial u_2}{\partial{\sigma_2}} & ... & 0\\
# ...&...&...&...\\
# 0 & 0 & ... & \frac{\partial u_D}{\partial{\sigma_D}}
# \end{bmatrix}=
# \begin{bmatrix}
# \frac{-1}{{\sigma_1}^2} & 0 & ... & 0\\
# 0 & \frac{1}{{\sigma_2}^2} & ... & 0\\
# ...&...&...&...\\
# 0 & 0 & ... & \frac{1}{{\sigma_D}^2}
# \end{bmatrix}\\
# & \vec{\sigma}=\sqrt{\vec{v}+\epsilon}
# & \rightarrow
# \underset{D\times D}{\frac{\partial \vec{\sigma}}{\partial \vec{v}}}& =
# \begin{bmatrix}
# \frac{1}{2\sqrt{v_1}} & 0 &...&0\\
# 0 & \frac{1}{2\sqrt{v_2}}&...&0\\
# 0 & 0 & ... & \frac{1}{2\sqrt{v_D}}
# \end{bmatrix}=
# \begin{bmatrix}
# \frac{1}{2\sigma_1} & 0 &...&0\\
# 0 & \frac{1}{2\sigma_2}&...&0\\
# 0 & 0 & ... & \frac{1}{2\sigma_D}
# \end{bmatrix}|
# \end{align*}
#
# &emsp;
# \begin{align*}
# \underset{1\times D}{\vec{v}}=
# \begin{bmatrix}
# v_1 & v_2 & ... & v_D
# \end{bmatrix} &=
# \begin{bmatrix}
# \frac{1}{N}\sum_{k=1}^N (x_{k1} - \mu_1)^2 & \frac{1}{N}\sum_{k=1}^N (x_{k2} - \mu_2)^2 &...& \frac{1}{N}\sum_{k=1}^N (x_{kD} - \mu_D)^2
# \end{bmatrix}\\
# \\
# ***\frac{\partial \hat{X}}{\partial \vec{\sigma}} \cdot \frac{\partial \vec{\sigma}}{\partial X} & =
# \frac{\partial \hat{X}}{\partial \vec{u}} \cdot  \frac{\partial \vec{u}}{\partial \vec{\sigma}} \cdot \frac{\partial \vec{\sigma}}{\partial \vec{v}} \cdot \frac{\partial \vec{v}}{\partial X}***\\
# \underset{N\times D\times D\times 1}{\frac{\partial \hat{X}}{\partial \vec{u}}}=
# \begin{bmatrix}
# \frac{\partial \vec{\hat{x_1}}}{\partial \vec{u}}\\
# \frac{\partial \vec{\hat{x_2}}}{\partial \vec{u}}\\
# ...\\
# \frac{\partial \vec{\hat{x_N}}}{\partial \vec{u}}
# \end{bmatrix}=
# \begin{bmatrix}
# \frac{\partial \vec{\hat{x_1}}}{\partial u_1} & \frac{\partial \vec{\hat{x_1}}}{\partial u_2} & ... & \frac{\partial \vec{\hat{x_1}}}{\partial u_D}\\
# \frac{\partial \vec{\hat{x_2}}}{\partial u_1} & \frac{\partial \vec{\hat{x_2}}}{\partial u_2} & ... & \frac{\partial \vec{\hat{x_2}}}{\partial u_D}\\
# ...\\
# \frac{\partial \vec{\hat{x_N}}}{\partial u_1} & \frac{\partial \vec{\hat{x_N}}}{\partial u_2} & ... & \frac{\partial \vec{\hat{x_N}}}{\partial u_D}
# \end{bmatrix};
# & \underset{D\times 1}{\frac{\partial \vec{\hat{x_i}}}{\partial u_j}}=
# \begin{bmatrix}
# \frac{\partial \hat{x_{i1}}}{\partial u_j}\\
# \frac{\partial \hat{x_{i2}}}{\partial u_j}\\
# ...\\
# \frac{\partial \hat{x_{ij}}}{\partial u_j}\\
# ...\\
# \frac{\partial \hat{x_{iD}}}{\partial u_j}
# \end{bmatrix}=
# \begin{bmatrix}
# 0\\
# 0\\
# ...\\
# x_{ij} -\mu_j\\
# ...\\
# 0
# \end{bmatrix};
# \end{align*}
#
# \begin{align*}
# We have: \underset{N\times D\times D\times 1}{\frac{\partial \hat{X}}{\partial \vec{u}}\cdot\frac{\partial \vec{u}}{\partial \vec{\sigma}}} & =
# \begin{bmatrix}
# \frac{\partial \vec{\hat{x_1}}}{\partial \vec{u}}\cdot\frac{\partial \vec{u}}{\partial \vec{\sigma}}\\
# \frac{\partial \vec{\hat{x_2}}}{\partial \vec{u}}\cdot\frac{\partial \vec{u}}{\partial \vec{\sigma}}\\
# ...\\
# \frac{\partial \vec{\hat{x_N}}}{\partial \vec{u}}\cdot\frac{\partial \vec{u}}{\partial \vec{\sigma}}
# \end{bmatrix}\\
# & = \begin{bmatrix}
# \frac{\partial \vec{\hat{x_1}}}{\partial u_1} \cdot \frac{\partial u_1}{\partial \sigma_1} + \frac{\partial \vec{\hat{x_1}}}{\partial u_2} \cdot \frac{\partial u_2}{\partial \sigma_1} + ... + \frac{\partial \vec{\hat{x_1}}}{\partial u_D} \cdot \frac{\partial u_D}{\partial \sigma_1} & \frac{\partial \vec{\hat{x_1}}}{\partial u_1} \cdot \frac{\partial u_1}{\partial \sigma_2} + \frac{\partial \vec{\hat{x_1}}}{\partial u_2} \cdot \frac{\partial u_2}{\partial \sigma_2} + ... + \frac{\partial \vec{\hat{x_1}}}{\partial u_D} \cdot \frac{\partial u_D}{\partial \sigma_2} & ... & \frac{\partial \vec{\hat{x_1}}}{\partial u_1} \cdot \frac{\partial u_1}{\partial \sigma_D} + \frac{\partial \vec{\hat{x_1}}}{\partial u_2} \cdot \frac{\partial u_2}{\partial \sigma_D} + ... + \frac{\partial \vec{\hat{x_1}}}{\partial u_D} \cdot \frac{\partial u_D}{\partial \sigma_D}\\
# \frac{\partial \vec{\hat{x_2}}}{\partial u_1} \cdot \frac{\partial u_1}{\partial \sigma_1} + \frac{\partial \vec{\hat{x_2}}}{\partial u_2} \cdot \frac{\partial u_2}{\partial \sigma_1} + ... + \frac{\partial \vec{\hat{x_2}}}{\partial u_D} \cdot \frac{\partial u_D}{\partial \sigma_1} & \frac{\partial \vec{\hat{x_2}}}{\partial u_1} \cdot \frac{\partial u_1}{\partial \sigma_2} + \frac{\partial \vec{\hat{x_2}}}{\partial u_2} \cdot \frac{\partial u_2}{\partial \sigma_2} + ... + \frac{\partial \vec{\hat{x_2}}}{\partial u_D} \cdot \frac{\partial u_D}{\partial \sigma_2}&...&\frac{\partial \vec{\hat{x_2}}}{\partial u_1} \cdot \frac{\partial u_1}{\partial \sigma_D} + \frac{\partial \vec{\hat{x_2}}}{\partial u_2} \cdot \frac{\partial u_2}{\partial \sigma_D} + ... + \frac{\partial \vec{\hat{x_2}}}{\partial u_D} \cdot \frac{\partial u_D}{\partial \sigma_D}\\
# ...\\
# \frac{\partial \vec{\hat{x_N}}}{\partial u_1} \cdot \frac{\partial u_1}{\partial \sigma_1} + \frac{\partial \vec{\hat{x_N}}}{\partial u_2} \cdot \frac{\partial u_2}{\partial \sigma_1} + ... + \frac{\partial \vec{\hat{x_N}}}{\partial u_D} \cdot \frac{\partial u_D}{\partial \sigma_1} & \frac{\partial \vec{\hat{x_N}}}{\partial u_1} \cdot \frac{\partial u_1}{\partial \sigma_2} + \frac{\partial \vec{\hat{x_N}}}{\partial u_2} \cdot \frac{\partial u_2}{\partial \sigma_2} + ... + \frac{\partial \vec{\hat{x_N}}}{\partial u_D} \cdot \frac{\partial u_D}{\partial \sigma_2} &...& \frac{\partial \vec{\hat{x_N}}}{\partial u_1} \cdot \frac{\partial u_1}{\partial \sigma_D} + \frac{\partial \vec{\hat{x_N}}}{\partial u_2} \cdot \frac{\partial u_2}{\partial \sigma_D} + ... + \frac{\partial \vec{\hat{x_N}}}{\partial u_D} \cdot \frac{\partial u_D}{\partial \sigma_D}\\
# \end{bmatrix}\\
# & = \begin{bmatrix}
# \frac{\partial \vec{\hat{x_1}}}{\partial u_1} \cdot \frac{\partial u_1}{\partial \sigma_1} & \frac{\partial \vec{\hat{x_1}}}{\partial u_2} \cdot \frac{\partial u_2}{\partial \sigma_2} & ... & \frac{\partial \vec{\hat{x_1}}}{\partial u_D} \cdot \frac{\partial u_D}{\partial \sigma_D}\\
# \frac{\partial \vec{\hat{x_2}}}{\partial u_1} \cdot \frac{\partial u_1}{\partial \sigma_1} & \frac{\partial \vec{\hat{x_2}}}{\partial u_2} \cdot \frac{\partial u_2}{\partial \sigma_2} & ... & \frac{\partial \vec{\hat{x_2}}}{\partial u_D} \cdot \frac{\partial u_D}{\partial \sigma_D}\\
# ...\\
# \frac{\partial \vec{\hat{x_N}}}{\partial u_1} \cdot \frac{\partial u_1}{\partial \sigma_1} & \frac{\partial \vec{\hat{x_N}}}{\partial u_2} \cdot \frac{\partial u_2}{\partial \sigma_2} & ... & \frac{\partial \vec{\hat{x_N}}}{\partial u_D} \cdot \frac{\partial u_D}{\partial \sigma_D}
# \end{bmatrix};\\
# Similarly:  \underset{N\times D\times D\times 1}{\frac{\partial \hat{X}}{\partial \vec{u}}\cdot\frac{\partial \vec{u}}{\partial \vec{\sigma}} \cdot \frac{\partial \vec{\sigma}}{\partial \vec{v}}}
# & = \begin{bmatrix}
# \frac{\partial \vec{\hat{x_1}}}{\partial \vec{u}}\cdot\frac{\partial \vec{u}}{\partial \vec{\sigma}}\\
# \frac{\partial \vec{\hat{x_2}}}{\partial \vec{u}}\cdot\frac{\partial \vec{u}}{\partial \vec{\sigma}}\\
# ...\\
# \frac{\partial \vec{\hat{x_N}}}{\partial \vec{u}}\cdot\frac{\partial \vec{u}}{\partial \vec{\sigma}}
# \end{bmatrix} = \begin{bmatrix}
# \frac{\partial \vec{\hat{x_1}}}{\partial u_1} \cdot \frac{\partial u_1}{\partial \sigma_1} \cdot \frac{\partial \sigma_1}{\partial v_1} & \frac{\partial \vec{\hat{x_1}}}{\partial u_2} \cdot \frac{\partial u_2}{\partial \sigma_2} \cdot \frac{\partial \sigma_2}{\partial v_2} & ... & \frac{\partial \vec{\hat{x_1}}}{\partial u_D} \cdot \frac{\partial u_D}{\partial \sigma_D} \cdot \frac{\partial \sigma_D}{\partial v_D}\\
# \frac{\partial \vec{\hat{x_2}}}{\partial u_1} \cdot \frac{\partial u_1}{\partial \sigma_1} \cdot \frac{\partial \sigma_1}{\partial v_1} & \frac{\partial \vec{\hat{x_2}}}{\partial u_2} \cdot \frac{\partial u_2}{\partial \sigma_2} \cdot \frac{\partial \sigma_2}{\partial v_2} & ... & \frac{\partial \vec{\hat{x_2}}}{\partial u_D} \cdot \frac{\partial u_D}{\partial \sigma_D} \cdot \frac{\partial \sigma_D}{\partial v_D}\\
# ...\\
# \frac{\partial \vec{\hat{x_N}}}{\partial u_1} \cdot \frac{\partial u_1}{\partial \sigma_1} \cdot \frac{\partial \sigma_1}{\partial v_1} & \frac{\partial \vec{\hat{x_N}}}{\partial u_2} \cdot \frac{\partial u_2}{\partial \sigma_2} \cdot \frac{\partial \sigma_2}{\partial v_2} & ... & \frac{\partial \vec{\hat{x_N}}}{\partial u_D} \cdot \frac{\partial u_D}{\partial \sigma_D} \cdot \frac{\partial \sigma_D}{\partial v_D}
# \end{bmatrix};\\
# And: \underset{D\times 1}{\frac{\partial \vec{\hat{x_i}}}{\partial u_j}\cdot\frac{\partial u_j}{\partial \sigma_j}\cdot\frac{\partial \sigma_j}{\partial v_j}}
# & = \begin{bmatrix}
# \frac{\partial \hat{x_{i1}}}{\partial u_j}\cdot\frac{\partial u_j}{\partial \sigma_j}\cdot\frac{\partial \sigma_j}{\partial v_j}\\
# \frac{\partial \hat{x_{i2}}}{\partial u_j}\cdot\frac{\partial u_j}{\partial \sigma_j}\cdot\frac{\partial \sigma_j}{\partial v_j}\\
# ...\\
# \frac{\partial \hat{x_{ij}}}{\partial u_j}\cdot\frac{\partial u_j}{\partial \sigma_j}\cdot\frac{\partial \sigma_j}{\partial v_j}\\
# ...\\
# \frac{\partial \hat{x_{iD}}}{\partial u_j}\cdot\frac{\partial u_j}{\partial \sigma_j}\cdot\frac{\partial \sigma_j}{\partial v_j}
# \end{bmatrix}=
# \begin{bmatrix}
# 0\\
# 0\\
# ...\\
# -\frac{x_{ij} -\mu_j}{2{\sigma_j^3}}\\
# ...\\
# 0
# \end{bmatrix};
# \end{align*}
#
# \begin{align*}
# ***\underset{1\times N\times D\times N}{\frac{\partial \vec{v}}{\partial X}} & =
# \begin{bmatrix}
# \frac{\partial \vec{v}}{\partial \vec{x_1}} & \frac{\partial \vec{v}}{\partial \vec{x_2}} & ... & \frac{\partial \vec{v}}{\partial \vec{x_N}}
# \end{bmatrix};
# \underset{D\times N}{\frac{\partial \vec{v}}{\partial \vec{x_i}}}=
# \begin{bmatrix}
# \frac{\partial v_1}{\partial \vec{x_i}}\\
# \frac{\partial v_2}{\partial \vec{x_i}}\\
# ...\\
# \frac{\partial v_i}{\partial \vec{x_i}}\\
# ...\\
# \frac{\partial v_D}{\partial \vec{x_i}}\\
# \end{bmatrix}=
# \begin{bmatrix}
# \frac{\partial v_1}{\partial x_{i1}} & \frac{\partial v_1}{\partial x_{i2}} & ... &\frac{\partial v_1}{\partial x_{iD}}\\
# \frac{\partial v_2}{\partial x_{i1}} & \frac{\partial v_2}{\partial x_{i2}} & ... &\frac{\partial v_2}{\partial x_{iD}}\\
# ...\\
# \frac{\partial v_i}{\partial x_{i1}} & \frac{\partial v_i}{\partial x_{i2}} & ... &\frac{\partial v_i}{\partial x_{iD}}\\
# ...\\
# \frac{\partial v_D}{\partial x_{i1}} & \frac{\partial v_D}{\partial x_{i2}} & ... &\frac{\partial v_D}{\partial x_{iD}}
# \end{bmatrix}\\
# \frac{\partial v_i}{\partial x_{ki}} & =\frac{2(x_{ki}-\mu_i)}{N} + \frac{\partial v_i}{\partial \mu_i}\cdot\frac{\partial \mu_i}{\partial x_{ki}}; \frac{\partial v_i}{\partial x_{kj}}=\frac{\partial v_i}{\partial \mu_i}\cdot\frac{\partial \mu_i}{\partial x_{kj}}\\
# But,\\
# \frac{\partial v_i}{\partial \mu_i} & =\frac{2\sum_{k=1}^N (x_{ki}-\mu_i)\times (-1)}{N}=\frac{-2}{N}(\sum_{k=1}^N x_{ki} - \sum_{k=1}^N \mu_i)\\
# & = \frac{-2}{N}(\sum_{k=1}^N x_{ki} - N\mu_i)=\frac{-2}{N}(\sum_{k=1}^N x_{ki} - \sum_{k=1}^N x_{ki})=0\\
# Hence,\\
# \underset{D\times N}{\frac{\partial \vec{v}}{\partial \vec{x_i}}} &=
# \begin{bmatrix}
# \frac{2(x_{i1}-\mu_1)}{N} & 0 &...&0\\
# 0 & \frac{2(x_{i2}-\mu_2)}{N} & ... & 0\\
# ...\\
# 0 & 0 &...& \frac{2(x_{iD}-\mu_D)}{N}
# \end{bmatrix};
# \end{align*}
#
# \begin{align*}
# Finally,\frac{\partial \hat{X}}{\partial \vec{u}}\cdot\frac{\partial \vec{u}}{\partial \vec{\sigma}} \cdot \frac{\partial \vec{\sigma}}{\partial \vec{v}} \cdot \frac{\partial \vec{v}}{\partial \vec{x_1}}=\\
# & \begin{bmatrix}
# \frac{\partial \vec{\hat{x_1}}}{\partial u_1} \cdot \frac{\partial u_1}{\partial \sigma_1} \cdot \frac{\partial \sigma_1}{\partial v_1} \cdot \frac{\partial v_1}{\partial x_{11}} + \frac{\partial \vec{\hat{x_1}}}{\partial u_2} \cdot \frac{\partial u_2}{\partial \sigma_2} \cdot \frac{\partial \sigma_2}{\partial v_2} \cdot \frac{\partial v_2}{\partial x_{11}} + ... +\frac{\partial \vec{\hat{x_1}}}{\partial u_D} \cdot \frac{\partial u_D}{\partial \sigma_D} \cdot \frac{\partial \sigma_D}{\partial v_D} \cdot \frac{\partial v_D}{\partial x_{11}} & \frac{\partial \vec{\hat{x_1}}}{\partial u_1} \cdot \frac{\partial u_1}{\partial \sigma_1} \cdot \frac{\partial \sigma_1}{\partial v_1} \cdot \frac{\partial v_1}{\partial x_{12}}+\frac{\partial \vec{\hat{x_1}}}{\partial u_2} \cdot \frac{\partial u_2}{\partial \sigma_2} \cdot \frac{\partial \sigma_2}{\partial v_2}\cdot \frac{\partial v_2}{\partial x_{12}} + ... + \frac{\partial \vec{\hat{x_1}}}{\partial u_D} \cdot \frac{\partial u_D}{\partial \sigma_D} \cdot \frac{\partial \sigma_D}{\partial v_D} \cdot \frac{\partial v_D}{\partial x_{12}} & ... & \frac{\partial \vec{\hat{x_1}}}{\partial u_1} \cdot \frac{\partial u_1}{\partial \sigma_1} \cdot \frac{\partial \sigma_1}{\partial v_1} \cdot \frac{\partial v_1}{\partial x_{1D}} + \frac{\partial \vec{\hat{x_1}}}{\partial u_2} \cdot \frac{\partial u_2}{\partial \sigma_2} \cdot \frac{\partial \sigma_2}{\partial v_2} \cdot \frac{\partial v_2}{\partial x_{1D}} +...+ \frac{\partial \vec{\hat{x_1}}}{\partial u_D} \cdot \frac{\partial u_D}{\partial \sigma_D} \cdot \frac{\partial \sigma_D}{\partial v_D} \cdot \frac{\partial v_D}{\partial x_{1D}}\\
# \frac{\partial \vec{\hat{x_2}}}{\partial u_1} \cdot \frac{\partial u_1}{\partial \sigma_1} \cdot \frac{\partial \sigma_1}{\partial v_1} \cdot \frac{\partial v_1}{\partial x_{11}} + \frac{\partial \vec{\hat{x_2}}}{\partial u_2} \cdot \frac{\partial u_2}{\partial \sigma_2} \cdot \frac{\partial \sigma_2}{\partial v_2} \cdot \frac{\partial v_2}{\partial x_{11}} + ... +\frac{\partial \vec{\hat{x_2}}}{\partial u_D} \cdot \frac{\partial u_D}{\partial \sigma_D} \cdot \frac{\partial \sigma_D}{\partial v_D} \cdot \frac{\partial v_D}{\partial x_{11}} & \frac{\partial \vec{\hat{x_2}}}{\partial u_1} \cdot \frac{\partial u_1}{\partial \sigma_1} \cdot \frac{\partial \sigma_1}{\partial v_1} \cdot \frac{\partial v_1}{\partial x_{12}}+\frac{\partial \vec{\hat{x_2}}}{\partial u_2} \cdot \frac{\partial u_2}{\partial \sigma_2} \cdot \frac{\partial \sigma_2}{\partial v_2}\cdot \frac{\partial v_2}{\partial x_{12}} + ... + \frac{\partial \vec{\hat{x_2}}}{\partial u_D} \cdot \frac{\partial u_D}{\partial \sigma_D} \cdot \frac{\partial \sigma_D}{\partial v_D} \cdot \frac{\partial v_D}{\partial x_{12}} & ... & \frac{\partial \vec{\hat{x_2}}}{\partial u_1} \cdot \frac{\partial u_1}{\partial \sigma_1} \cdot \frac{\partial \sigma_1}{\partial v_1} \cdot \frac{\partial v_1}{\partial x_{1D}} + \frac{\partial \vec{\hat{x_2}}}{\partial u_2} \cdot \frac{\partial u_2}{\partial \sigma_2} \cdot \frac{\partial \sigma_2}{\partial v_2} \cdot \frac{\partial v_2}{\partial x_{1D}} +...+ \frac{\partial \vec{\hat{x_2}}}{\partial u_D} \cdot \frac{\partial u_D}{\partial \sigma_D} \cdot \frac{\partial \sigma_D}{\partial v_D} \cdot \frac{\partial v_D}{\partial x_{1D}}\\
# ...\\
# \frac{\partial \vec{\hat{x_N}}}{\partial u_1} \cdot \frac{\partial u_1}{\partial \sigma_1} \cdot \frac{\partial \sigma_1}{\partial v_1} \cdot \frac{\partial v_1}{\partial x_{11}} + \frac{\partial \vec{\hat{x_N}}}{\partial u_2} \cdot \frac{\partial u_2}{\partial \sigma_2} \cdot \frac{\partial \sigma_2}{\partial v_2} \cdot \frac{\partial v_2}{\partial x_{11}} + ... +\frac{\partial \vec{\hat{x_N}}}{\partial u_D} \cdot \frac{\partial u_D}{\partial \sigma_D} \cdot \frac{\partial \sigma_D}{\partial v_D} \cdot \frac{\partial v_D}{\partial x_{11}} & \frac{\partial \vec{\hat{x_N}}}{\partial u_1} \cdot \frac{\partial u_1}{\partial \sigma_1} \cdot \frac{\partial \sigma_1}{\partial v_1} \cdot \frac{\partial v_1}{\partial x_{12}}+\frac{\partial \vec{\hat{x_N}}}{\partial u_2} \cdot \frac{\partial u_2}{\partial \sigma_2} \cdot \frac{\partial \sigma_2}{\partial v_2}\cdot \frac{\partial v_2}{\partial x_{12}} + ... + \frac{\partial \vec{\hat{x_N}}}{\partial u_D} \cdot \frac{\partial u_D}{\partial \sigma_D} \cdot \frac{\partial \sigma_D}{\partial v_D} \cdot \frac{\partial v_D}{\partial x_{12}} & ... & \frac{\partial \vec{\hat{x_N}}}{\partial u_1} \cdot \frac{\partial u_1}{\partial \sigma_1} \cdot \frac{\partial \sigma_1}{\partial v_1} \cdot \frac{\partial v_1}{\partial x_{1D}} + \frac{\partial \vec{\hat{x_N}}}{\partial u_2} \cdot \frac{\partial u_2}{\partial \sigma_2} \cdot \frac{\partial \sigma_2}{\partial v_2} \cdot \frac{\partial v_2}{\partial x_{1D}} +...+ \frac{\partial \vec{\hat{x_N}}}{\partial u_D} \cdot \frac{\partial u_D}{\partial \sigma_D} \cdot \frac{\partial \sigma_D}{\partial v_D} \cdot \frac{\partial v_D}{\partial x_{1D}}
# \end{bmatrix}\\
# \\
# &= \begin{bmatrix}
# \frac{\partial \vec{\hat{x_1}}}{\partial u_1} \cdot \frac{\partial u_1}{\partial \sigma_1} \cdot \frac{\partial \sigma_1}{\partial v_1} \cdot \frac{\partial v_1}{\partial x_{11}} & \frac{\partial \vec{\hat{x_1}}}{\partial u_2} \cdot \frac{\partial u_2}{\partial \sigma_2} \cdot \frac{\partial \sigma_2}{\partial v_2}\cdot \frac{\partial v_2}{\partial x_{12}} & ... & \frac{\partial \vec{\hat{x_1}}}{\partial u_D} \cdot \frac{\partial u_D}{\partial \sigma_D} \cdot \frac{\partial \sigma_D}{\partial v_D} \cdot \frac{\partial v_D}{\partial x_{1D}}\\
# \frac{\partial \vec{\hat{x_2}}}{\partial u_1} \cdot \frac{\partial u_1}{\partial \sigma_1} \cdot \frac{\partial \sigma_1}{\partial v_1} \cdot \frac{\partial v_1}{\partial x_{11}} & \frac{\partial \vec{\hat{x_2}}}{\partial u_2} \cdot \frac{\partial u_2}{\partial \sigma_2} \cdot \frac{\partial \sigma_2}{\partial v_2}\cdot \frac{\partial v_2}{\partial x_{12}} & ... & \frac{\partial \vec{\hat{x_2}}}{\partial u_D} \cdot \frac{\partial u_D}{\partial \sigma_D} \cdot \frac{\partial \sigma_D}{\partial v_D} \cdot \frac{\partial v_D}{\partial x_{1D}}\\
# ...\\
# \frac{\partial \vec{\hat{x_N}}}{\partial u_1} \cdot \frac{\partial u_1}{\partial \sigma_1} \cdot \frac{\partial \sigma_1}{\partial v_1} \cdot \frac{\partial v_1}{\partial x_{11}} & \frac{\partial \vec{\hat{x_N}}}{\partial u_2} \cdot \frac{\partial u_2}{\partial \sigma_2} \cdot \frac{\partial \sigma_2}{\partial v_2}\cdot \frac{\partial v_2}{\partial x_{12}} & ... & \frac{\partial \vec{\hat{x_N}}}{\partial u_D} \cdot \frac{\partial u_D}{\partial \sigma_D} \cdot \frac{\partial \sigma_D}{\partial v_D} \cdot \frac{\partial v_D}{\partial x_{1D}}
# \end{bmatrix}\\
# Or: \underset{N\times N\times D\times D}{\frac{\partial \hat{X}}{\partial X}} &=
# \begin{bmatrix}
# \frac{\partial \vec{\hat{x_1}}}{\partial \vec{x_1}} & \frac{\partial \vec{\hat{x_1}}}{\partial \vec{x_2}} &...& \frac{\partial \vec{\hat{x_1}}}{\partial \vec{x_N}}\\
# \frac{\partial \vec{\hat{x_2}}}{\partial \vec{x_1}} & \frac{\partial \vec{\hat{x_2}}}{\partial \vec{x_2}} &...& \frac{\partial \vec{\hat{x_2}}}{\partial \vec{x_N}}\\
# ...\\
# \frac{\partial \vec{\hat{x_N}}}{\partial \vec{x_1}} & \frac{\partial \vec{\hat{x_N}}}{\partial \vec{x_2}} &...& \frac{\partial \vec{\hat{x_N}}}{\partial \vec{x_N}}
# \end{bmatrix};
# \underset{D\times D}{\frac{\partial \vec{\hat{x_j}}}{\partial \vec{x_k}}}=
# \begin{bmatrix}
# 0 & 0 &...& 0\\
# ...\\
# \frac{-(x_{j1}-\mu_1)(x_{k1}-\mu_1)}{N(\sigma_1^3)} & \frac{-(x_{j2}-\mu_2)(x_{k2}-\mu_2)}{N(\sigma_2^3)} & ... & \frac{-(x_{jD}-\mu_D)(x_{kD}-\mu_D)}{N(\sigma_D^3)}\\
# ...\\
# 0 & 0 &...& 0
# \end{bmatrix}
# \end{align*}
#
# \begin{align*}
# Then: \underset{N\times D}{\frac{\partial l}{\partial Y} \cdot \frac{\partial Y}{\partial \hat{X}} \cdot \frac{\partial \hat{X}}{\partial \vec{\sigma}} \cdot \frac{\partial \vec{\sigma}}{\partial X}} &=
# \begin{bmatrix}
# \frac{\partial \vec{\hat{x_1}}}{\partial \vec{\sigma}} \cdot \frac{\partial \vec{\sigma}}{\partial \vec{x_1}} & \frac{\partial \vec{\hat{x_1}}}{\partial \vec{\sigma}} \cdot \frac{\partial \vec{\sigma}}{\partial \vec{x_2}} &...&\frac{\partial \vec{\hat{x_1}}}{\partial \vec{\sigma}} \cdot \frac{\partial \vec{\sigma}}{\partial \vec{x_N}}\\
# \frac{\partial \vec{\hat{x_2}}}{\partial \vec{\sigma}} \cdot \frac{\partial \vec{\sigma}}{\partial \vec{x_1}} & \frac{\partial \vec{\hat{x_2}}}{\partial \vec{\sigma}} \cdot \frac{\partial \vec{\sigma}}{\partial \vec{x_2}} &...&\frac{\partial \vec{\hat{x_2}}}{\partial \vec{\sigma}} \cdot \frac{\partial \vec{\sigma}}{\partial \vec{x_N}}\\
# & & ... &...\\
# \frac{\partial \vec{\hat{x_N}}}{\partial \vec{\sigma}} \cdot \frac{\partial \vec{\sigma}}{\partial \vec{x_1}} & \frac{\partial \vec{\hat{x_N}}}{\partial \vec{\sigma}} \cdot \frac{\partial \vec{\sigma}}{\partial \vec{x_2}} &...&\frac{\partial \vec{\hat{x_N}}}{\partial \vec{\sigma}} \cdot \frac{\partial \vec{\sigma}}{\partial \vec{x_N}}
# \end{bmatrix} \cdot
# \begin{bmatrix}
#     \gamma_1\frac{\partial l}{\partial \vec{y_1}}\\
#     \gamma_2\frac{\partial l}{\partial \vec{y_2}}\\
#     ...\\
#     \gamma_N \frac{\partial l}{\partial \vec{y_N}}
# \end{bmatrix}\\
# &=\begin{bmatrix}
#     \gamma_1\frac{\partial l}{\partial \vec{y_1}} \cdot (\frac{\partial \vec{\hat{x_1}}}{\partial \vec{\sigma}} \cdot \frac{\partial \vec{\sigma}}{\partial \vec{x_1}}) + \gamma_2\frac{\partial l}{\partial \vec{y_2}} \cdot (\frac{\partial \vec{\hat{x_1}}}{\partial \vec{\sigma}} \cdot \frac{\partial \vec{\sigma}}{\partial \vec{x_2}})+ ...+ \gamma_N \frac{\partial l}{\partial \vec{y_N}} \cdot (\frac{\partial \vec{\hat{x_1}}}{\partial \vec{\sigma}} \cdot \frac{\partial \vec{\sigma}}{\partial \vec{x_N}}) \\
#     \gamma_1\frac{\partial l}{\partial \vec{y_1}} \cdot (\frac{\partial \vec{\hat{x_2}}}{\partial \vec{\sigma}} \cdot \frac{\partial \vec{\sigma}}{\partial \vec{x_1}}) + \gamma_2\frac{\partial l}{\partial \vec{y_2}} \cdot (\frac{\partial \vec{\hat{x_2}}}{\partial \vec{\sigma}} \cdot \frac{\partial \vec{\sigma}}{\partial \vec{x_2}})+ ...+ \gamma_N \frac{\partial l}{\partial \vec{y_N}} \cdot (\frac{\partial \vec{\hat{x_2}}}{\partial \vec{\sigma}} \cdot \frac{\partial \vec{\sigma}}{\partial \vec{x_N}}) \\
#     ...\\
#     \gamma_1\frac{\partial l}{\partial \vec{y_1}} \cdot (\frac{\partial \vec{\hat{x_N}}}{\partial \vec{\sigma}} \cdot \frac{\partial \vec{\sigma}}{\partial \vec{x_1}}) + \gamma_2\frac{\partial l}{\partial \vec{y_2}} \cdot (\frac{\partial \vec{\hat{x_N}}}{\partial \vec{\sigma}} \cdot \frac{\partial \vec{\sigma}}{\partial \vec{x_2}})+ ...+\gamma_N \frac{\partial l}{\partial \vec{y_N}} \cdot (\frac{\partial \vec{\hat{x_N}}}{\partial \vec{\sigma}} \cdot \frac{\partial \vec{\sigma}}{\partial \vec{x_N}})
# \end{bmatrix}
# \end{align*}
#
# \begin{align*}
# Consider\space 1st\space row: & \gamma_1\frac{\partial l}{\partial \vec{y_1}} \cdot (\frac{\partial \vec{\hat{x_1}}}{\partial \vec{\sigma}} \cdot \frac{\partial \vec{\sigma}}{\partial \vec{x_1}}) + \gamma_2\frac{\partial l}{\partial \vec{y_2}} \cdot (\frac{\partial \vec{\hat{x_1}}}{\partial \vec{\sigma}} \cdot \frac{\partial \vec{\sigma}}{\partial \vec{x_2}})+ ...+ \gamma_N \frac{\partial l}{\partial \vec{y_N}} \cdot (\frac{\partial \vec{\hat{x_1}}}{\partial \vec{\sigma}} \cdot \frac{\partial \vec{\sigma}}{\partial \vec{x_N}})\\
# &=\gamma_1 \cdot
# \begin{bmatrix}
# \frac{\partial l}{\partial y_{11}} & \frac{\partial l}{\partial y_{12}} &...& \frac{\partial l}{\partial y_{1D}}
# \end{bmatrix} \cdot
# \begin{bmatrix}
# \frac{-(x_{11}-\mu_1)^2}{N(\sigma_1)^3} & \frac{-(x_{1D}-\mu_2)^2}{N(\sigma_2)^3} & ... & \frac{-(x_{1D}-\mu_D)^2}{N(\sigma_D)^3}\\
# 0 & 0 & ... & 0\\
# ...\\
# 0 & 0 & ... & 0
# \end{bmatrix}\\
# &+ \gamma_2 \cdot \begin{bmatrix}
# \frac{\partial l}{\partial y_{21}} & \frac{\partial l}{\partial y_{22}} &...& \frac{\partial l}{\partial y_{2D}}
# \end{bmatrix}\cdot
# \begin{bmatrix}
# \frac{-(x_{11}-\mu_1)(x_{21}-\mu_1)}{N(\sigma_1)^3} & \frac{-(x_{12}-\mu_2)(x_{22}-\mu_2)}{N(\sigma_2)^3} & ... & \frac{-(x_{1D}-\mu_D)(x_{2D}-\mu_D)}{N(\sigma_D)^3}\\
# 0 & 0 & ... & 0\\
# ...\\
# 0 & 0 & ... & 0
# \end{bmatrix}\\
# &+...+\gamma_N\cdot\begin{bmatrix}
# \frac{\partial l}{\partial y_{N1}} & \frac{\partial l}{\partial y_{N2}} &...& \frac{\partial l}{\partial y_{ND}}
# \end{bmatrix}\cdot
# \begin{bmatrix}
# \frac{-(x_{11}-\mu_1)(x_{N1}-\mu_1)}{N(\sigma_1)^3} & \frac{-(x_{12}-\mu_2)(x_{N2}-\mu_2)}{N(\sigma_2)^3} & ... & \frac{-(x_{1D}-\mu_D)(x_{ND}-\mu_D)}{N(\sigma_D)^3}\\
# 0 & 0 & ... & 0\\
# ...\\
# 0 & 0 & ... & 0
# \end{bmatrix}\\
# \\
# =&\begin{bmatrix}
# \gamma_1\cdot\frac{\partial l}{\partial y_{11}}\cdot\frac{1}{N\sigma_1}\cdot\frac{-(x_{11}-\mu_1)}{\sigma_1}\cdot\frac{(x_{11}-\mu_1)}{\sigma_1} + \gamma_2\cdot\frac{\partial l}{\partial y_{21}}\cdot\frac{1}{N\sigma_1}\cdot\frac{-(x_{11}-\mu_1)}{\sigma_1}\cdot\frac{(x_{21}-\mu_1)}{\sigma_1}+ ... + \gamma_N\cdot\frac{\partial l}{\partial y_{N1}}\cdot\frac{1}{N\sigma_1}\cdot\frac{-(x_{11}-\mu_1)}{\sigma_1}\cdot\frac{(x_{N1}-\mu_1)}{\sigma_1} & \gamma_1\cdot\frac{\partial l}{\partial y_{12}}\cdot\frac{1}{N\sigma_2}\cdot\frac{-(x_{12}-\mu_2)}{\sigma_2}\cdot\frac{(x_{12}-\mu_2)}{\sigma_2} + \gamma_2\cdot\frac{\partial l}{\partial y_{22}}\cdot\frac{1}{N\sigma_2}\cdot\frac{-(x_{12}-\mu_2)}{\sigma_2}\cdot\frac{(x_{22}-\mu_2)}{\sigma_2}+ ... + \gamma_N\cdot\frac{\partial l}{\partial y_{N2}}\cdot\frac{1}{N\sigma_2}\cdot\frac{-(x_{12}-\mu_2)}{\sigma_2}\cdot\frac{(x_{N2}-\mu_2)}{\sigma_2} & ... & \gamma_1\cdot\frac{\partial l}{\partial y_{1D}}\cdot\frac{1}{N\sigma_D}\cdot\frac{-(x_{1D}-\mu_D)}{\sigma_D}\cdot\frac{(x_{1D}-\mu_D)}{\sigma_D} + \gamma_2\cdot\frac{\partial l}{\partial y_{2D}}\cdot\frac{1}{N\sigma_D}\cdot\frac{-(x_{1D}-\mu_D)}{\sigma_D}\cdot\frac{(x_{2D}-\mu_D)}{\sigma_D}+ ... + \gamma_N\cdot\frac{\partial l}{\partial y_{ND}}\cdot\frac{1}{N\sigma_D}\cdot\frac{-(x_{1D}-\mu_D)}{\sigma_D}\cdot\frac{(x_{ND}-\mu_D)}{\sigma_D}
# \end{bmatrix}\\
# =&\begin{bmatrix}
# \gamma_1\cdot\frac{\partial l}{\partial y_{11}}\cdot\frac{1}{N\sigma_1}\cdot(\hat{-x_{11}})\cdot\hat{x_{11}} + \gamma_2\cdot\frac{\partial l}{\partial y_{21}}\cdot\frac{1}{N\sigma_1}\cdot(\hat{-x_{11}})\cdot\hat{x_{21}}+ ... + \gamma_N\cdot\frac{\partial l}{\partial y_{N1}}\cdot\frac{1}{N\sigma_1}\cdot(\hat{-x_{11}})\cdot\hat{x_{N1}} & \gamma_1\cdot\frac{\partial l}{\partial y_{12}}\cdot\frac{1}{N\sigma_2}\cdot(\hat{-x_{12}})\cdot\hat{x_{12}} + \gamma_2\cdot\frac{\partial l}{\partial y_{22}}\cdot\frac{1}{N\sigma_2}\cdot(\hat{-x_{12}})\cdot\hat{x_{22}}+ ... + \gamma_N\cdot\frac{\partial l}{\partial y_{N2}}\cdot\frac{1}{N\sigma_2}\cdot(\hat{-x_{12}})\cdot\hat{x_{N2}} & ... &  \gamma_1\cdot\frac{\partial l}{\partial y_{1D}}\cdot\frac{1}{N\sigma_D}\cdot(\hat{-x_{1D}})\cdot\hat{x_{1D}} + \gamma_2\cdot\frac{\partial l}{\partial y_{2D}}\cdot\frac{1}{N\sigma_D}\cdot(\hat{-x_{1D}})\cdot\hat{x_{2D}}+ ... + \gamma_N\cdot\frac{\partial l}{\partial y_{ND}}\cdot\frac{1}{N\sigma_D}\cdot(\hat{-x_{1D}})\cdot\hat{x_{ND}}
# \end{bmatrix}\\
# =&\frac{\vec{-\hat{x_{1}}}}{N\sigma_1}\begin{bmatrix}\gamma_1\cdot\frac{\partial l}{\partial y_{11}}\cdot\hat{x_{11}} + \gamma_2\cdot\frac{\partial l}{\partial y_{21}}\cdot\hat{x_{21}}+ ... + \gamma_N\cdot\frac{\partial l}{\partial y_{N1}}\cdot\hat{x_{N1}} & \gamma_1\cdot\frac{\partial l}{\partial y_{12}}\cdot\hat{x_{12}} + \gamma_2\cdot\frac{\partial l}{\partial y_{22}}\cdot\hat{x_{22}}+ ... + \gamma_N\cdot\frac{\partial l}{\partial y_{N2}}\cdot\hat{x_{N2}} &...& \gamma_1\cdot\frac{\partial l}{\partial y_{1D}}\cdot\hat{x_{1D}} + \gamma_2\cdot\frac{\partial l}{\partial y_{2D}}\cdot\hat{x_{2D}}+ ... + \gamma_N\cdot\frac{\partial l}{\partial y_{ND}}\cdot\hat{x_{ND}}
# \end{bmatrix}
# \end{align*}
# \begin{align*}
# &Similarly\space second\space row,\\
# & \gamma_1\frac{\partial l}{\partial \vec{y_1}} \cdot (\frac{\partial \vec{\hat{x_2}}}{\partial \vec{\sigma}} \cdot \frac{\partial \vec{\sigma}}{\partial \vec{x_1}}) + \gamma_2\frac{\partial l}{\partial \vec{y_2}} \cdot (\frac{\partial \vec{\hat{x_2}}}{\partial \vec{\sigma}} \cdot \frac{\partial \vec{\sigma}}{\partial \vec{x_2}})+ ...+ \gamma_N \frac{\partial l}{\partial \vec{y_N}} \cdot (\frac{\partial \vec{\hat{x_2}}}{\partial \vec{\sigma}} \cdot \frac{\partial \vec{\sigma}}{\partial \vec{x_N}})\\
# &={\frac{-\vec{\hat{x_{2}}}}{N\sigma_2}\begin{bmatrix}\gamma_1\cdot\frac{\partial l}{\partial y_{11}}\cdot\hat{x_{11}} + \gamma_2\cdot\frac{\partial l}{\partial y_{21}}\cdot\hat{x_{21}}+ ... + \gamma_N\cdot\frac{\partial l}{\partial y_{N1}}\cdot\hat{x_{N1}} & \gamma_1\cdot\frac{\partial l}{\partial y_{12}}\cdot\hat{x_{12}} + \gamma_2\cdot\frac{\partial l}{\partial y_{22}}\cdot\hat{x_{22}}+ ... + \gamma_N\cdot\frac{\partial l}{\partial y_{N2}}\cdot\hat{x_{N2}} &...& \gamma_1\cdot\frac{\partial l}{\partial y_{1D}}\cdot\hat{x_{1D}} + \gamma_2\cdot\frac{\partial l}{\partial y_{2D}}\cdot\hat{x_{2D}}+ ... + \gamma_N\cdot\frac{\partial l}{\partial y_{ND}}\cdot\hat{x_{ND}}\end{bmatrix}}\\
# &Or\space ith\space row,\\
# & \gamma_1\frac{\partial l}{\partial \vec{y_1}} \cdot (\frac{\partial \vec{\hat{x_i}}}{\partial \vec{\sigma}} \cdot \frac{\partial \vec{\sigma}}{\partial \vec{x_1}}) + \gamma_2\frac{\partial l}{\partial \vec{y_2}} \cdot (\frac{\partial \vec{\hat{x_i}}}{\partial \vec{\sigma}} \cdot \frac{\partial \vec{\sigma}}{\partial \vec{x_2}})+ ...+ \gamma_N \frac{\partial l}{\partial \vec{y_N}} \cdot (\frac{\partial \vec{\hat{x_i}}}{\partial \vec{\sigma}} \cdot \frac{\partial \vec{\sigma}}{\partial \vec{x_N}})\\
# &=\frac{\vec{-\hat{x_{i}}}}{N\sigma_i}\begin{bmatrix}
# \gamma_1\cdot\frac{\partial l}{\partial y_{11}}\cdot\hat{x_{11}} + \gamma_2\cdot\frac{\partial l}{\partial y_{21}}\cdot\hat{x_{21}}+ ... + \gamma_N\cdot\frac{\partial l}{\partial y_{N1}}\cdot\hat{x_{N1}} & \gamma_1\cdot\frac{\partial l}{\partial y_{12}}\cdot\hat{x_{12}} + \gamma_2\cdot\frac{\partial l}{\partial y_{22}}\cdot\hat{x_{22}}+ ... + \gamma_N\cdot\frac{\partial l}{\partial y_{N2}}\cdot\hat{x_{N2}} &...& \gamma_1\cdot\frac{\partial l}{\partial y_{1D}}\cdot\hat{x_{1D}} + \gamma_2\cdot\frac{\partial l}{\partial y_{2D}}\cdot\hat{x_{2D}}+ ... + \gamma_N\cdot\frac{\partial l}{\partial y_{ND}}\cdot\hat{x_{ND}}
# \end{bmatrix}\\
# \\
# ***&Eventually,\space we\space have:\space \underset{N\times D}{\frac{\partial l}{\partial Y} \cdot \frac{\partial Y}{\partial \hat{X}} \cdot \frac{\partial \hat{X}}{\partial \vec{\sigma}} \cdot \frac{\partial \vec{\sigma}}{\partial X}}=
# \frac{-\hat{X}}{N\vec{\sigma}} * \sum_{axis=0} (\frac{\partial l}{\partial Y} * \hat{X} )***
# \end{align*}
