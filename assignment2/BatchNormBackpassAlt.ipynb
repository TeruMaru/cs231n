# %% [markdown]
# $$\vec{\hat{x_i}}=\frac{\vec{x_i} - \vec{\mu}}{\vec{\sigma}}$$
#
# \begin{gather}
# \rightarrow \hat{X} = \frac{X - \vec{\mu}}{\vec{\sigma}}=
# \begin{bmatrix}
#     \vec{\hat{x^T_1}}\\
#     \vec{\hat{x^T_2}}\\
#     ...
#     \vec{\hat{x^T_N}}\\
# \end{bmatrix}=
# \begin{bmatrix}
#     \frac{\vec{x^T_1} - \vec{\mu_1}}{\vec{\sigma_1}}\\
#     \frac{\vec{x^T_2} - \vec{\mu_2}}{\vec{\sigma_2}}\\
#     ...\\
#     \frac{\vec{x^T_N} - \vec{\mu_N}}{\vec{\sigma_N}}\\
# \end{bmatrix}=
# \begin{bmatrix}
#     \frac{x_{11} - \mu_1}{\sigma_1} & \frac{x_{12} - \mu_2}{\sigma_2} & ... & \frac{x_{1D} - \mu_D}{\sigma_D}\\
#     \frac{x_{21} - \mu_1}{\sigma_1} & \frac{x_{22} - \mu_2}{\sigma_2} & ... & \frac{x_{2D} - \mu_D}{\sigma_D} \\
#     &  & ... & \\
#     \frac{x_{N1} - \mu_1}{\sigma_1} & \frac{x_{N2} - \mu_2}{\sigma_2} & ... & \frac{x_{ND} - \mu_D}{\sigma_D}\\
# \end{bmatrix}
# \end{gather}
#
# ***

# %% [markdown]
# &emsp;
# $$\frac{\partial l}{\partial X}= \frac{\partial l}{\partial Y} \cdot \frac{\partial Y}{\partial \hat{X}} \cdot(\frac{\partial \hat{X}}{\partial X} +\frac{\partial \hat{X}}{\partial \vec{\mu}} \cdot \frac{\partial  \vec{\mu}}{\partial X} + \frac{\partial \hat{X}}{\partial \vec{\sigma}} \cdot \frac{\partial  \vec{\sigma}}{\partial X} )$$
#
# &emsp;
# ***

# %% [markdown]
# 1/ Calculate $\frac{\partial l}{\partial Y} \cdot \frac{\partial Y}{\partial \hat{X}} \cdot\frac{\partial \hat{X}}{\partial X}$
# \begin{gather}
#     \underset{N\times N}{\frac{\partial \hat{X}}{\partial X}}=
#     \begin{bmatrix}
#        \frac{\partial \vec{\hat{x_1}}}{\partial \vec{x_1}} & \frac{\partial \vec{\hat{x_1}}}{\partial \vec{x_2}} & ... & \frac{\partial \vec{\hat{x_1}}}{\partial \vec{x_N}}\\
#        \frac{\partial \vec{\hat{x_2}}}{\partial \vec{x_1}} & \frac{\partial \vec{\hat{x_2}}}{\partial \vec{x_2}} & ... & \frac{\partial \vec{\hat{x_2}}}{\partial \vec{x_N}}\\
#        ... & ... & ... & ...\\
#         \frac{\partial \vec{\hat{x_N}}}{\partial \vec{x_1}} & \frac{\partial \vec{\hat{x_N}}}{\partial \vec{x_2}} & ... & \frac{\partial \vec{\hat{x_N}}}{\partial \vec{x_N}}
#     \end{bmatrix}=
#     \begin{bmatrix}
#        \frac{\partial \vec{\hat{x_1}}}{\partial \vec{x_1}} & 0 & ... & 0\\
#        0 & \frac{\partial \vec{\hat{x_2}}}{\partial \vec{x_2}} & ... & ...\\
#        ... & ... & ... & ...\\
#        0 & 0 & ... & \frac{\partial \vec{\hat{x_N}}}{\partial \vec{x_N}}
#     \end{bmatrix}
# \end{gather}
#
# &emsp;
# \begin{gather}
# \underset{N\times D}{\frac{\partial l}{\partial Y} \cdot \frac{\partial Y}{\partial \hat{X}} \cdot \frac{\partial \hat{X}}{\partial X}}=
# \begin{bmatrix}
#     \frac{\partial \vec{\hat{x_1}}}{\partial \vec{x_1}} & 0 & ... & 0\\
#     0 & \frac{\partial \vec{\hat{x_2}}}{\partial \vec{x_2}} & ... & ...\\
#     ... & ... & ... & ...\\
#     0 & 0 & ... & \frac{\partial \vec{\hat{x_N}}}{\partial \vec{x_N}}
# \end{bmatrix} \cdot
# \begin{bmatrix}
#     \gamma_1\frac{\partial l}{\partial \vec{y_1}}\\
#     \gamma_2\frac{\partial l}{\partial \vec{y_2}}\\
#     ...\\
#     \gamma_N \frac{\partial l}{\partial \vec{y_N}}
# \end{bmatrix}=
# \begin{bmatrix}
#     \gamma_1\frac{\partial l}{\partial \vec{y_1}} \cdot \frac{\partial \vec{\hat{x_1}}}{\partial \vec{x_1}}\\
#     \gamma_2\frac{\partial l}{\partial \vec{y_2}} \cdot \frac{\partial \vec{\hat{x_2}}}{\partial \vec{x_2}}\\
#     ...\\
#     \gamma_N \frac{\partial l}{\partial \vec{y_N}} \cdot \frac{\partial \vec{\hat{x_N}}}{\partial \vec{x_N}}
# \end{bmatrix};
# & \underset{D\times D}{\frac{\partial\vec{\hat{x_i}}}{\partial\vec{x_i}}}=
#     \begin{bmatrix}
#        \frac{\partial \hat{x_{i1}}}{\partial x_{i1}} & \frac{\partial \hat{x_{i1}}}{\partial x_{i2}} & ... & \frac{\partial \hat{x_{i1}}}{\partial x_{iD}}\\
#        \frac{\partial \hat{x_{i2}}}{\partial x_{i1}} & \frac{\partial \hat{x_{i2}}}{\partial x_{i2}} & ... & \frac{\partial \hat{x_{i2}}}{\partial x_{iD}}\\
#        ... & ... & ... & ...\\
#        \frac{\partial \hat{x_{iD}}}{\partial x_{i1}} & \frac{\partial \hat{x_{iD}}}{\partial x_{i2}} & ... & \frac{\partial \hat{x_{iD}}}{\partial x_{iD}}
#     \end{bmatrix}=
#     \begin{bmatrix}
#        \frac{\partial \hat{x_{i1}}}{\partial x_{i1}} & 0 & ... & 0\\
#        0 & \frac{\partial \hat{x_{i2}}}{\partial x_{i1}} & ... & ...\\
#        ... & ... & ... & ...\\
#        0 & 0 & ... & \frac{\partial \hat{x_{iD}}}{\partial x_{iD}}
#     \end{bmatrix}
# \end{gather}
#
# ***Hence,
# \begin{gather}
# \underset{N\times D}{\frac{\partial l}{\partial Y} \cdot \frac{\partial Y}{\partial \hat{X}} \cdot \frac{\partial \hat{X}}{\partial X}}=
# \vec{\gamma} * \frac{\partial l}{\partial Y} *
# \underset{N\times D}{\begin{bmatrix}
# \frac{1}{\sigma_1} & \frac{1}{\sigma_1} &...& \frac{1}{\sigma_1}\\
# \frac{1}{\sigma_2} & \frac{1}{\sigma_2} &...& \frac{1}{\sigma_2}\\
# ...\\
# \frac{1}{\sigma_N} & \frac{1}{\sigma_N} &...& \frac{1}{\sigma_N}
# \end{bmatrix}}
# \end{gather}***
# ***

# %% [markdown]
# ***

# %% [markdown]
# 2/ Calculate $\frac{\partial l}{\partial Y} \cdot \frac{\partial Y}{\partial \hat{X}} \cdot\frac{\partial \hat{X}}{\partial \vec{\mu}}\cdot\frac{\partial \vec{\mu}}{X}$
#
# \begin{gather}
# \underset{1\times D}{\vec{\mu}}=
# \begin{bmatrix}
# \mu_1 & \mu_2 & ... & \mu_D
# \end{bmatrix}=
# \begin{bmatrix}
# \frac{1}{N}\sum_{k=1}^N x_{k1} & \frac{1}{N}\sum_{k=1}^N x_{k2} &...& \frac{1}{N}\sum_{k=1}^N x_{kD}
# \end{bmatrix}
# \end{gather}
# &emsp;
# \begin{gather}
# & \underset{N\times N\times D\times 1}{\frac{\partial \hat{X}}{\partial \vec{\mu}}}=
# \begin{bmatrix}
# \frac{\partial \vec{\hat{x_1}}}{\partial \vec{\mu}}\\
# \frac{\partial \vec{\hat{x_2}}}{\partial \vec{\mu}}\\
# ...\\
# \frac{\partial \vec{\hat{x_N}}}{\partial \vec{\mu}}\\
# \end{bmatrix}=
# \begin{bmatrix}
# \frac{\partial \vec{\hat{x_1}}}{\partial \mu_1} & \frac{\partial \vec{\hat{x_1}}}{\partial \mu_2} & ... & \frac{\partial \vec{\hat{x_1}}}{\partial \mu_D}\\
# \frac{\partial \vec{\hat{x_2}}}{\partial \mu_1} & \frac{\partial \vec{\hat{x_2}}}{\partial \mu_2} & ... & \frac{\partial \vec{\hat{x_2}}}{\partial \mu_D}\\
# ...\\
# \frac{\partial \vec{\hat{x_N}}}{\partial \mu_1} & \frac{\partial \vec{\hat{x_N}}}{\partial \mu_2} & ... & \frac{\partial \vec{\hat{x_N}}}{\partial \mu_D}
# \end{bmatrix};
# & \underset{D\times 1}{\frac{\partial \vec{\hat{x_i}}}{\partial \mu_j}}=
# \begin{bmatrix}
# \frac{\partial \hat{x_{i1}}}{\partial \mu_j} \\
# \frac{\partial \hat{x_{i2}}}{\partial \mu_j} \\
# ... \\
# \frac{\partial \hat{x_{ij}}}{\partial \mu_j}\\
# ... \\
# \frac{\partial \hat{x_{iD}}}{\partial \mu_j}
# \end{bmatrix}=
# \begin{bmatrix}
# 0 \\
# 0 \\
# ... \\
# \frac{-1}{\sigma_j}\\
# ... \\
# 0
# \end{bmatrix}
# \end{gather}
# &emsp;
# \begin{gather}
# \underset{N\times D\times D}{\frac{\partial \vec{\mu}}{\partial X}}=
# \begin{bmatrix}
# \frac{\partial \vec{\mu}}{\partial \vec{x_1}} & \frac{\partial \vec{\mu}}{\partial \vec{x_2}} & ... & \frac{\partial \vec{\mu}}{\partial \vec{x_N}}
# \end{bmatrix};
# & \underset{D\times D}{\frac{\partial \vec{\mu}}{\partial \vec{x_i}}}=
# \begin{bmatrix}
# \frac{\partial \mu_1}{\partial \vec{x_i}} \\
# \frac{\partial \mu_2}{\partial \vec{x_i}} \\
# ... \\
# \frac{\partial \mu_i}{\partial \vec{x_i}} \\
# ... \\
# \frac{\partial \mu_D}{\partial \vec{x_i}}
# \end{bmatrix}=
# \begin{bmatrix}
# \frac{1}{N} & 0 & ... & 0 \\
# 0 & \frac{1}{N} & ... & 0 \\
# & &...& & \\
# 0 & 0 & ... & \frac{1}{N}
# \end{bmatrix}
# \end{gather}
# &emsp;
# Hence,
# \begin{gather}
# \underset{N\times N\times D\times D}{\frac{\partial l}{\partial Y} \cdot \frac{\partial Y}{\partial \hat{X}} \cdot\frac{\partial \hat{X}}{\partial \vec{\mu}}\cdot\frac{\partial \vec{\mu}}{X}}=
# \begin{bmatrix}
# \frac{\partial \vec{\hat{x_1}}}{\partial \vec{x_1}} & \frac{\partial \vec{\hat{x_1}}}{\partial \vec{x_2}} & ... & \frac{\partial  \vec{\hat{x_1}}}{\partial \vec{x_N}}\\
# \frac{\partial \vec{\hat{x_2}}}{\partial \vec{x_1}} & \frac{\partial \vec{\hat{x_2}}}{\partial \vec{x_2}} & ... & \frac{\partial \vec{\hat{x_2}}}{\partial \vec{x_N}}\\
# & & ... &\\
# \frac{\partial \vec{\hat{x_N}}}{\partial \vec{x_1}} & \frac{\partial \vec{\hat{x_N}}}{\partial \vec{x_2}} & ... & \frac{\partial \vec{\hat{x_N}}}{\partial \vec{x_N}}\\
# \end{bmatrix}=
# \begin{bmatrix}
# \frac{\partial \vec{\hat{x_1}}}{\partial \vec{\mu}} \cdot \frac{\partial \vec{\mu}}{\partial \vec{x_1}} & \frac{\partial \vec{\hat{x_1}}}{\partial \vec{\mu}} \cdot \frac{\partial \vec{\mu}}{\partial \vec{x_2}} &...&\frac{\partial \vec{\hat{x_1}}}{\partial \vec{\mu}} \cdot \frac{\partial \vec{\mu}}{\partial \vec{x_N}}\\
# \frac{\partial \vec{\hat{x_2}}}{\partial \vec{\mu}} \cdot \frac{\partial \vec{\mu}}{\partial \vec{x_1}} & \frac{\partial \vec{\hat{x_2}}}{\partial \vec{\mu}} \cdot \frac{\partial \vec{\mu}}{\partial \vec{x_2}} &...&\frac{\partial \vec{\hat{x_2}}}{\partial \vec{\mu}} \cdot \frac{\partial \vec{\mu}}{\partial \vec{x_N}}\\
# & & ... &...\\
# \frac{\partial \vec{\hat{x_N}}}{\partial \vec{\mu}} \cdot \frac{\partial \vec{\mu}}{\partial \vec{x_1}} & \frac{\partial \vec{\hat{x_N}}}{\partial \vec{\mu}} \cdot \frac{\partial \vec{\mu}}{\partial \vec{x_2}} &...&\frac{\partial \vec{\hat{x_N}}}{\partial \vec{\mu}} \cdot \frac{\partial \vec{\mu}}{\partial \vec{x_N}}
# \end{bmatrix}
# \end{gather}
#
# We have,
# \begin{gather}
# \underset{D\times D}{\frac{\partial \vec{\hat{x_i}}}{\partial \vec{\mu}} \cdot \frac{\partial \vec{\mu}}{\partial \vec{x_j}}}=$
# \frac{\partial \vec{\hat{x_i}}}{\partial \mu_1} \cdot \frac{\partial \mu_1}{\partial \vec{x_j}} +...+ \frac{\partial \vec{\hat{x_i}}}{\partial \mu_i} \cdot \frac{\partial \mu_i}{\partial \vec{x_j}} +...+ \frac{\partial \vec{\hat{x_i}}}{\partial \mu_N} \cdot \frac{\partial \mu_N}{\partial \vec{x_j}}
# \end{gather}
# \begin{gather}
# =\begin{bmatrix}
# \frac{-1}{\sigma_1}\\
# 0\\
# ...\\
# 0
# \end{bmatrix} \cdot
# \begin{bmatrix}
# \frac{1}{N} & 0 & ... & 0
# \end{bmatrix} +
# \begin{bmatrix}
# 0\\
# \frac{-1}{\sigma_2}\\
# ...\\
# 0
# \end{bmatrix} \cdot
# \begin{bmatrix}
# 0 & \frac{1}{N} & ... & 0
# \end{bmatrix} + ... +
# \begin{bmatrix}
# 0\\
# 0\\
# ...\\
# \frac{-1}{\sigma_D}
# \end{bmatrix} \cdot
# \begin{bmatrix}
# 0 & 0 & ... & \frac{1}{N}
# \end{bmatrix}=
# \begin{bmatrix}
# \frac{-1}{N\sigma_1} & 0 & ... & 0\\
# 0 & \frac{-1}{N\sigma_2} & ... & 0\\
# ... & ... & ... & ...\\
# 0 & 0 & ... & \frac{-1}{N\sigma_D}
# \end{bmatrix}
# \end{gather}

# %% [markdown]
# So,
# \begin{gather}
# \underset{N\times D}{\frac{\partial l}{\partial Y} \cdot \frac{\partial Y}{\partial \hat{X}} \cdot \frac{\partial \hat{X}}{\partial \vec{\mu}} \cdot \frac{\partial \vec{\mu}}{\partial X}}=
# \begin{bmatrix}
# \frac{\partial \vec{\hat{x_1}}}{\partial \vec{\mu}} \cdot \frac{\partial \vec{\mu}}{\partial \vec{x_1}} & \frac{\partial \vec{\hat{x_1}}}{\partial \vec{\mu}} \cdot \frac{\partial \vec{\mu}}{\partial \vec{x_2}} &...&\frac{\partial \vec{\hat{x_1}}}{\partial \vec{\mu}} \cdot \frac{\partial \vec{\mu}}{\partial \vec{x_N}}\\
# \frac{\partial \vec{\hat{x_2}}}{\partial \vec{\mu}} \cdot \frac{\partial \vec{\mu}}{\partial \vec{x_1}} & \frac{\partial \vec{\hat{x_2}}}{\partial \vec{\mu}} \cdot \frac{\partial \vec{\mu}}{\partial \vec{x_2}} &...&\frac{\partial \vec{\hat{x_2}}}{\partial \vec{\mu}} \cdot \frac{\partial \vec{\mu}}{\partial \vec{x_N}}\\
# & & ... &...\\
# \frac{\partial \vec{\hat{x_N}}}{\partial \vec{\mu}} \cdot \frac{\partial \vec{\mu}}{\partial \vec{x_1}} & \frac{\partial \vec{\hat{x_N}}}{\partial \vec{\mu}} \cdot \frac{\partial \vec{\mu}}{\partial \vec{x_2}} &...&\frac{\partial \vec{\hat{x_N}}}{\partial \vec{\mu}} \cdot \frac{\partial \vec{\mu}}{\partial \vec{x_N}}
# \end{bmatrix} \cdot
# \begin{bmatrix}
#     \gamma_1\frac{\partial l}{\partial \vec{y_1}}\\
#     \gamma_2\frac{\partial l}{\partial \vec{y_2}}\\
#     ...\\
#     \gamma_N \frac{\partial l}{\partial \vec{y_N}}
# \end{bmatrix}=
# \begin{bmatrix}
#     \gamma_1\frac{\partial l}{\partial \vec{y_1}} \cdot (\frac{\partial \vec{\hat{x_1}}}{\partial \vec{\mu}} \cdot \frac{\partial \vec{\mu}}{\partial \vec{x_1}}) + \gamma_2\frac{\partial l}{\partial \vec{y_2}} \cdot (\frac{\partial \vec{\hat{x_1}}}{\partial \vec{\mu}} \cdot \frac{\partial \vec{\mu}}{\partial \vec{x_2}})+ ...+ \gamma_N \frac{\partial l}{\partial \vec{y_N}} \cdot (\frac{\partial \vec{\hat{x_1}}}{\partial \vec{\mu}} \cdot \frac{\partial \vec{\mu}}{\partial \vec{x_N}}) \\
#     \gamma_1\frac{\partial l}{\partial \vec{y_1}} \cdot (\frac{\partial \vec{\hat{x_2}}}{\partial \vec{\mu}} \cdot \frac{\partial \vec{\mu}}{\partial \vec{x_1}}) + \gamma_2\frac{\partial l}{\partial \vec{y_2}} \cdot (\frac{\partial \vec{\hat{x_2}}}{\partial \vec{\mu}} \cdot \frac{\partial \vec{\mu}}{\partial \vec{x_2}})+ ...+ \gamma_N \frac{\partial l}{\partial \vec{y_N}} \cdot (\frac{\partial \vec{\hat{x_2}}}{\partial \vec{\mu}} \cdot \frac{\partial \vec{\mu}}{\partial \vec{x_N}}) \\
#     ...\\
#     \gamma_1\frac{\partial l}{\partial \vec{y_1}} \cdot (\frac{\partial \vec{\hat{x_N}}}{\partial \vec{\mu}} \cdot \frac{\partial \vec{\mu}}{\partial \vec{x_1}}) + \gamma_2\frac{\partial l}{\partial \vec{y_2}} \cdot (\frac{\partial \vec{\hat{x_N}}}{\partial \vec{\mu}} \cdot \frac{\partial \vec{\mu}}{\partial \vec{x_2}})+ ...+\gamma_N \frac{\partial l}{\partial \vec{y_N}} \cdot (\frac{\partial \vec{\hat{x_N}}}{\partial \vec{\mu}} \cdot \frac{\partial \vec{\mu}}{\partial \vec{x_N}})
# \end{bmatrix}=
# \begin{bmatrix}
# (\sum_{k=1}^N \gamma_k\frac{\partial l}{\partial \vec{{y_k}^T}}) \cdot (\frac{\partial \vec{\hat{x_i}}}{\partial \vec{\mu}} \cdot \frac{\partial \vec{\mu}}{\partial \vec{x_j}})\\
# ...\\
# (\sum_{k=1}^N \gamma_k\frac{\partial l}{\partial \vec{{y_k}^T}}) \cdot (\frac{\partial \vec{\hat{x_i}}}{\partial \vec{\mu}} \cdot \frac{\partial \vec{\mu}}{\partial \vec{x_j}})
# \end{bmatrix}
# \end{gather}
#
# ***Ultimately,
# \begin{gather}
# \underset{N\times D}{\frac{\partial l}{\partial Y} \cdot \frac{\partial Y}{\partial \hat{X}} \cdot \frac{\partial \hat{X}}{\partial \vec{\mu}} \cdot \frac{\partial \vec{\mu}}{\partial X}}=
# \begin{bmatrix}
# (\sum_{k=1}^N \gamma_k\frac{\partial l}{\partial \vec{{y_k}^T}})\\
# ...\\
# (\sum_{k=1}^N \gamma_k\frac{\partial l}{\partial \vec{{y_k}^T}})
# \end{bmatrix} *
# \begin{bmatrix}
# \frac{-1}{N\sigma_1} & \frac{-1}{N\sigma_2} & ... & \frac{-1}{N\sigma_D}\\
# ...\\
# \frac{-1}{N\sigma_1} & \frac{-1}{N\sigma_2} & ... & \frac{-1}{N\sigma_D}
# \end{bmatrix}
# \end{gather}***
# ***

# %% [markdown]
# ***
